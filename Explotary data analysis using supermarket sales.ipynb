# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("supermarket_sales - sheet1.xls",parse_dates = ['Date','Time'])

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# Display Top 5 Rows of the dataset

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#                  Time      Payment    cogs  gross margin percentage  \
# 0 2023-03-02 13:08:00      Ewallet  522.83                 4.761905
# 1 2023-03-02 10:29:00         Cash   76.40                 4.761905
# 2 2023-03-02 13:23:00  Credit card  324.31                 4.761905
# 3 2023-03-02 20:33:00      Ewallet  465.76                 4.761905
# 4 2023-03-02 10:37:00      Ewallet  604.17                 4.761905
#
#    gross income  Rating
# 0       26.1415     9.1
# 1        3.8200     9.6
# 2       16.2155     7.4
# 3       23.2880     8.4
# 4       30.2085     5.3

# %% [markdown]
# Display Last 5 Rows of the Dataset

# %%
data.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date                Time  \
# 995       40.35         1   2.0175    42.3675 2019-01-29 2023-03-02 13:46:00
# 996       97.38        10  48.6900  1022.4900 2019-03-02 2023-03-02 17:16:00
# 997       31.84         1   1.5920    33.4320 2019-02-09 2023-03-02 13:22:00
# 998       65.82         1   3.2910    69.1110 2019-02-22 2023-03-02 15:33:00
# 999       88.34         7  30.9190   649.2990 2019-02-18 2023-03-02 13:28:00
#
#      Payment    cogs  gross margin percentage  gross income  Rating
# 995  Ewallet   40.35                 4.761905        2.0175     6.2
# 996  Ewallet  973.80                 4.761905       48.6900     4.4
# 997     Cash   31.84                 4.761905        1.5920     7.7
# 998     Cash   65.82                 4.761905        3.2910     4.1
# 999     Cash  618.38                 4.761905       30.9190     6.6

# %% [markdown]
# Print Random 5 Rows of the Dataset

# %%
data.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 320  649-11-3678      C  Naypyitaw        Normal  Female
# 585  127-47-6963      A     Yangon        Normal    Male
# 828  538-22-0304      C  Naypyitaw        Normal    Male
# 59   120-06-4233      C  Naypyitaw        Normal    Male
# 563  760-90-2357      A     Yangon        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 320      Food and beverages       22.93         9  10.3185  216.6885
# 585       Health and beauty       51.71         4  10.3420  217.1820
# 828  Electronic accessories       64.95        10  32.4750  681.9750
# 59   Electronic accessories       30.61         6   9.1830  192.8430
# 563  Electronic accessories       74.51         6  22.3530  469.4130
#
#           Date                Time      Payment    cogs  \
# 320 2019-02-26 2023-03-02 20:26:00         Cash  206.37
# 585 2019-03-09 2023-03-02 13:53:00  Credit card  206.84
# 828 2019-03-24 2023-03-02 18:27:00         Cash  649.50
# 59  2019-03-12 2023-03-02 20:36:00         Cash  183.66
# 563 2019-03-20 2023-03-02 15:08:00      Ewallet  447.06
#
#      gross margin percentage  gross income  Rating
# 320                 4.761905       10.3185     5.5
# 585                 4.761905       10.3420     9.8
# 828                 4.761905       32.4750     5.2
# 59                  4.761905        9.1830     9.3
# 563                 4.761905       22.3530     5.0

# %% [markdown]
# Find Shape of Our Dataset(Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (1000, 17)

# %%
print("Number of columns",data.shape[1])
print("Number of rows",data.shape[0])
# Out:
# Number of columns 17
# Number of rows 1000

# %% [markdown]
# 5.Check for null values in the Dataset

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# 6.Get information About Our Dataset Like Total Number Rows, Total Number of Columns,
# Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   datetime64[ns]
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: datetime64[ns](2), float64(7), int64(1), object(7)
# memory usage: 132.9+ KB

# %% [markdown]
# 7.Get Overall Statistics About the Dataset

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# 25%               4.761905e+00      5.924875     5.50000
# 50%               4.761905e+00     12.088000     7.00000
# 75%               4.761905e+00     22.445250     8.50000
# max               4.761905e+00     49.650000    10.00000

# %%
cat = []
num = []
for column in data.columns:
    if data[column].nunique()>10:
        num.append(column)
    else:
        cat.append(column)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %% [markdown]
# Univariate Analysis

# %% [markdown]
# 1.Find Aggregate Sales Among Branches.(Categorical Column)

# %%
sns.countplot(data["Branch"])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %%
data["Branch"].value_counts().plot(kind= 'pie',autopct = "%1.2f%%")
# Out:
# <AxesSubplot:ylabel='Branch'>

# %% [markdown]
# 2.Find The Most Popular Payment Method Used By Customers (Categorical column)

# %%
data["Payment"].value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# 3.Find The Distribution Of Customer Ratings.(Numerical Column)

# %%
sns.distplot(data["Rating"])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %%
data['Rating'].skew()
# Out:
# 0.00900964876573073

# %% [markdown]
# 4.Find the Distribution of Cost of Goods Sold (Numerical Column)

# %%
sns.distplot(data["cogs"])
# Out:
# <AxesSubplot:xlabel='cogs', ylabel='Density'>

# %%
data["cogs"].skew()
# Out:
# 0.8925698049581418

# %%
sns.boxplot(data["cogs"])
# Out:
# <AxesSubplot:xlabel='cogs'>

# %% [markdown]
# Bivariate Analysis/Multivariate Analysis

# %% [markdown]
# 1.Does The Cost of Goods Sold Affect The Ratings That The Customers Provide?(Numerical-Numerical)

# %%
sns.scatterplot(data["cogs"],data["Rating"])
# Out:
# <AxesSubplot:xlabel='cogs', ylabel='Rating'>

# %% [markdown]
# 2.Does Gross Income Affect The Ratings That The Customers Provide?(Numerical-Numerical)

# %%
sns.scatterplot(data["gross income"],data["Rating"])
# Out:
# <AxesSubplot:xlabel='gross income', ylabel='Rating'>

# %% [markdown]
# 3.Find the Most Profitable Branch As Per Gross Income.(Numerical-Categorical)

# %%
sns.barplot(data["Branch"],data["gross income"])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='gross income'>

# %%
sns.barplot(data["Branch"],data["gross income"],hue=data["City"])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='gross income'>

# %% [markdown]
# 4.Is There Any Relationship Between Gender And Gross Income?(Numerical-Categorical)

# %%
sns.boxplot(data["Gender"],data["gross income"])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='gross income'>

# %%
sns.boxplot(data["Gender"],data["gross income"],hue=data["Customer type"])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='gross income'>

# %% [markdown]
# 5.Find The Product Line That Generates The Most Income.(Numerical-Categorical)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sns.barplot(data["Product line"],data["gross income"])
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(data["Product line"],data["Unit price"])
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 7.Find The Highest Unit Price In The Product Line.(Numerical-Categorical)

# %%
sns.barplot(data["Product line"],data["Unit price"])
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 7.Find Different Payment Methods Used By Customers Citywise.(Categorical-Categorical)

# %%
pd.crosstab(data["City"],data["Payment"])
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(pd.crosstab(data["City"],data["Payment"]))
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='City'>

# %% [markdown]
# 8.Which Product Line is Purchased In The Highest Quantity?

# %%
(data.groupby('Product line').sum()['Quantity']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Product line'>

# %% [markdown]
# 9.Display Daily Sales By Day of the Week

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
dw_mapping = {
    0:'Mon',
    1:'Tue',
    2:'Wed',
    3:'Thu',
    4:'Fri',
    5:'Sat',
    6:'Sun'
}

# %%
data['day_of_week']=data['Date'].dt.dayofweek.map(dw_mapping)

# %%
data['day_of_week'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 10.What Will Be the Highest Months for Sales

# %%
month_mapping = {
    1:"Jan",
    2:"Feb",
    3:"Mar"
}

# %%
data['month']=data['Date'].dt.month.map(month_mapping)

# %%
data['month'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
